# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
from ydata_profiling import ProfileReport

prof = ProfileReport(df, explorative=True)
prof.to_file("output.html")
# Out:
# 100%|██████████| 12/12 [00:00<?, ?it/s]17 [00:00<00:00, 21.60it/s, Describe variable: Embarked]
# Summarize dataset:  74%|███████▎  | 14/19 [00:00<00:00, 15.63it/s, Calculate auto correlation]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 from ydata_profiling import ProfileReport
#       3 prof = ProfileReport(df, explorative=True)
# ----> 4 prof.to_file("output.html")
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)    496
#     497     """
# --> 498     return self.html
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)    426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:270, in ProfileReport.description_set(self)
#     267 @property
#     268 def description_set(self) -> BaseDescription:
#     269     if self._description_set is None:
# --> 270         self._description_set = describe_df(
#     271             self.config,
#     272             self.df,
#     273             self.summarizer,
#     274             self.typeset,
#     275             self._sample,
#     276         )
#     277     return self._description_set
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\describe.py:122, in describe(config, df, summarizer, typeset, sample)
#     118 correlation_names = get_active_correlations(config)
#     119 pbar.total += len(correlation_names)
#     121 correlations = {
# --> 122     correlation_name: progress(
#     123         calculate_correlation,
#     124         pbar,
#     125         f"Calculate {correlation_name} correlation",
#     126     )(config, df, correlation_name, series_description)
#     127     for correlation_name in correlation_names
#     128 }
#     130 # make sure correlations is not None
#     131 correlations = {
#     132     key: value for key, value in correlations.items() if value is not None
#     133 }
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\utils\progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\correlations.py:125, in calculate_correlation(config, df, correlation_name, summary)
#     123 correlation = None
#     124 try:
# --> 125     correlation = correlation_measures[correlation_name]().compute(
#     126         config, df, summary, backend
#     127     )
#     128 except (ValueError, AssertionError, TypeError, DataError, IndexError) as e:
#     129     warn_correlation(correlation_name, str(e))
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\correlations.py:57, in Correlation.compute(self, config, df, summary, backend)
#      55     raise NotImplementedError() from ex
#      56 else:
# ---> 57     return method(config, df, summary)
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\pandas\correlations_pandas.py:199, in auto_compute(config, df, summary)
#     192     def f(col_name: str, method: Callable) -> pd.Series:
#     193         return (
#     194             df_discretized
#     195             if col_name in numerical_columns and method is _pairwise_cramers
#     196             else df
#     197         )
# --> 199     score = method(
#     200         f(col_1_name, method)[col_1_name], f(col_2_name, method)[col_2_name]
#     201     )
#     202     (
#     203         correlation_matrix.loc[col_1_name, col_2_name],
#     204         correlation_matrix.loc[col_2_name, col_1_name],
#     205     ) = (score, score)
#     207 return correlation_matrix
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\pandas\correlations_pandas.py:72, in _pairwise_spearman(col_1, col_2)
#      71 def _pairwise_spearman(col_1: pd.Series, col_2: pd.Series) -> float:
# ---> 72     return col_1.corr(col_2, method="spearman")
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:2987, in Series.corr(self, other, method, min_periods)
#    2984 if len(this) == 0:
#    2985     return np.nan
# -> 2987 this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2988 other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2990 if method in ["pearson", "spearman", "kendall"] or callable(method):
#
# File c:\Users\tanes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:660, in IndexOpsMixin.to_numpy(self, dtype, copy, na_value, **kwargs)
#     655 if fillna:
#     656     if not can_hold_element(values, na_value):
#     657         # if we can't hold the na_value asarray either makes a copy or we
#     658         # error before modifying values. The asarray later on thus won't make
#     659         # another copy
# --> 660         values = np.asarray(values, dtype=dtype)
#     661     else:
#     662         values = values.copy()
#
# KeyboardInterrupt:
